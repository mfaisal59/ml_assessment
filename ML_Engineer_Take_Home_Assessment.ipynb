# %% [markdown]
# <a href="https://colab.research.google.com/github/mfaisal59/ml_assessment/blob/main/ML_Engineer_Take_Home_Assessment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Design and Train an object detector to detect objects
#
# You have to design and implement a Training Pipeline that can train, test and visualize the model using the dataset provided.
#
# ## Assignment Protocols
#
# - We expect it to take ~4 hours, with an extra 15 min for clear loom explanation(s)
#   - The assessment is timeboxed at 5 hours total in a single block. So please plan accordingly
# - You need to use Google Collaboratory to run and edit this notebook
# - You can only use Python as a programming Language
# - You cannot take help from any other person
# - You can use Google to search for references
# - You can not search on google for design-related things, like what should be loss function, or what should be model architecture.
#   - But you can use pre-trained backbones from PyTorch
# - Record a 5-10 mins of code walkthrough of the work you have done. You can use Loom Platform (https://www.loom.com) to record the video.
#   - Design Decisions
#     - Model Design which layers and activation functions you used and why
#     - Loss function, which loss functions you used and why
#     - Metrics, which metrics and why
#   - Any optimizations you have made to the codebase
#   - How you implemented resume functionality, what were the things you thought would be needed to resume training from exact same point
#   - Explain what parts of the assessment are completed and what is missing?
#   - Make sure to submit the screen recording link in the submission after you are done recording
#   - Please note that the free plan on Loom only allows for videos up to 5 minutes in length. As such, you may need to record two separate 5-minute videos.
# - [NO SUBMISSION WILL BE ACCEPTED WITHOUT]
#   - Trained best model weights
#   - Visualize Function in the Notebook
#   - Code Walk-through video
#
# ## Task Details
# Design a Training Pipeline to train a object detector with following specs or assumptions:
# - Implement & Design Model
#   - You can use any backbone
#     - Either from PyTorch (torhvision) or any resource online
#     - But you need to design head your self (head means how you will use features of the back bone and get the desired outputs)
#   - Model needs to detect one object in each image
#   - Model should output following for each image passed as input:
#     - Whether we have an object or not
#     - Where is the object?
#       - The bounding box output format should be xmin, ymin, xmax, ymax
#       - It is not necessary the model is trained to output exactly this format but the visualize function which shows output should output in this format
#     - Either the object is a cat or dog?
#     - And which specie the object belongs to? There are in total 9 species:
#       - Cat [3 species]:
#         - Abyssinian
#         - Birman
#         - Persian
#       - Dog [6 species]
#         - american_bulldog
#         - american_pit_bull_terrier
#         - basset_hound
#         - beagle
#         - chihuahua
#         - pomeranian
# - Implement Custom Dataloader
#   - This is obvious as dataset is in a unique format any predifined dataloader wont work
#   - Follow best practices of writing custom dataloaders
#   - Details of the format of the dataset are defined in the Dataset Details section below
#   - Add needed pre-processing that you think would help train a better model or would help as we are using pre-trained weights as starting point
#   - Add augmentations that you think would help train a better model
# - Implement Loss Function
#   - Design and implement a loss function that can handle all of the outputs we have
#   - You can use pytorch built-in loss functions
#   - There are many scenarios which you need to handle, which one can understand from the dataset details and the model design
# - Implement Test Function
#   - The test function should be able to run the model on the validation set and output the metrics for all the outputs of the model
#   - Select the metrics carefully, there are many scenarios which can change the selection of a metric
#   - Keep in mind there are multiple outputs, you would need a metric for each output
#   - [NOTE] You don't need to implement metrics for the bounding box output as it can take more time than provided for this assessment. But please add details of the metrics you would have implemented in your code-walk through loom video.
# - Update Resume Training Functionality using the best weights
#   - Current script does not have save best weights functionality
#   - The code should be able to resume training from exactly same point from where the training was stopped if model weights file is passed
#   - Keep in mind you can not resume training from same point by just loading weights of the model
# - Implement a visualize function [Most important, without this no submission will be accepted]
#   - The input of the function should be path of a folder with images and the weight file
#     - Also the output folder path to save outputs
#   - This function should return a dictionary of dictionaries with following details for each image:
#     - {
#         "has_object": True,
#         "cat_or_dog": "cat",
#         "specie": "persian",
#         "xmin": 10,
#         "ymin": 10,
#         "xmax": 10,
#         "ymax": 10
#     }
#   - And in case there is no object it should have 0 for bbox values, "NA" for "cat_or_dog" and "specie", and False for "has_object".
#   - Values of the returned dictionary should be like explained above and keys should be image names including the extension ".jpg" or ".jpeg"
#   - Should save output image with bounding box drawn on it, with same name input image but place in the output folder
# - Try to train the best model
#
#
# ## Dataset Details
# The dataset has in total 1041 images. Each image has a single object which is either a cat or a dog.
# - There are multiple species for both cat and dog.
# - The number of images falling in each specie is as follows:
#   - basset_hound: 93
#   - Birman: 93
#   - pomeranian: 93
#   - american_pit_bull_terrier: 93
#   - american_bulldog: 93
#   - Abyssinian: 92
#   - beagle: 93
#   - Persian: 93
#   - chihuahua: 93
#   - empty: 142
# - The dataset has two folders:
#   - images
#     - Inside images folder we have 986 images in .jpg folder
#   - labels
#     - Inside labels folder we have 899 .xml files each file with details of image labels
#     - For any image that does not have a cat or dog, there is no corresponding xml file
#
# ## Deliverable
# - Updated Colab Based Jupyter Notebook:
#   - With all the required functionality Implemented
#   - Which one can train the model without any errors
#   - One should achieve same metrics (Almost same metrics) if I run training using this collab notebook
#     - Set default values for everything accordingly in the notebook
#   - During evaluation we will just run the notebook and use the best weights the notebook saves automatically
# - Best weights you have trained
#   - We will Evaluate your weights against hold-out test we have and compare results
#   - We will use visualize function to generate outputs for each image
#   - Upload weights in an easily downloadable location like, Dropbox, Google Drive, Github, etc
# - A video code-walk through explaining your design decisions including but not limited to:
#   - Model Design which layers and activation functions you used and why
#   - Loss function, which loss functions you used and why
#   - Metrics, which metrics and why
#   - Any optimizations you have made to the codebase
#   - How you implemented resume functionality, what were the things you thought would be needed to resume training from exact same point
#
#
# ## Evaluation Criteria
#  - Design Decisions
#  - Completeness: Did you include all features?
#  - Correctness: Does the solution (all deliverables) work in sensible, thought-out ways?
#  - Maintainability: Is the code written in a clean, maintainable way?
#  - Testing: Is the solution adequately tested?
#  - Documentation: Is the codebase well-documented and has proper steps to run any of the deliverables?
#
# ## Extra Points
# - Add metrics for the Bounding Box Output
# - Any Updates in the notebook (Bugs/Implementation Mistakes etc)
#
# ## How to submit
# - Please upload the Notebook for this project to GitHub, and post a link to your repository below [repo link box, on the left of submit button].
#   - Create a new GitHub repository from scratch
#   - Add the final Colab/Jupyter notebook to the repository
# - Please upload video and your final best weights on Google Drive or any other platform, and paste the link to the folder with both video and model in the text box just above the submit button.
# - Please paste the commit Id of the latest commit of your Github Repo, which should not be later than 5 hours of time when the repo was created.
#   - Please note the submission without the commit id will not be considered.

# %% [markdown]
# # Install Required Modules

# %%
! pip install bs4 lxml kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1257 sha256=d2280ab0c457d5d25bb7db5ba0cc59e4ccf9f8592ef69a3117ba246edec23fc6
#   Stored in directory: /root/.cache/pip/wheels/25/42/45/b773edc52acb16cd2db4cf1a0b47117e2f69bb4eb300ed0e70
# Successfully built bs4
# ...

# %% [markdown]
# # Download Dataset from Kaggle

# %%
import os
os.environ['KAGGLE_USERNAME'] = 'bilalyousaf0014'
os.environ['KAGGLE_KEY'] = '11031bc21c5e3ec23585dbe17dc4267d'

# %%
# !kaggle datasets download -d bilalyousaf0014/ml-engineer-assessment-dataset
# Out:
# ...
#  73% 57.0M/78.6M [00:00<00:00, 207MB/s]
# 100% 78.6M/78.6M [00:00<00:00, 202MB/s]

# %%
! unzip /content/ml-engineer-assessment-dataset.zip
# Out:
# Archive:  /content/ml-engineer-assessment-dataset.zip
#   inflating: assessment_dataset/images/00001.jpeg
#   inflating: assessment_dataset/images/00008.jpeg
#   inflating: assessment_dataset/images/00017.jpeg
#   inflating: assessment_dataset/images/00022.jpeg
#   inflating: assessment_dataset/images/00048.jpeg
#   inflating: assessment_dataset/images/00055.jpeg
#   inflating: assessment_dataset/images/001.jpeg
#   inflating: assessment_dataset/images/1.jpeg
#   inflating: assessment_dataset/images/1001524.jpeg
#   inflating: assessment_dataset/images/1005343.jpeg
#   inflating: assessment_dataset/images/1049854.jpeg
#   inflating: assessment_dataset/images/1072860.jpeg
#   inflating: assessment_dataset/images/1120419.jpeg
#   inflating: assessment_dataset/images/1146885.jpeg
#   inflating: assessment_dataset/images/2.jpeg
#   inflating: assessment_dataset/images/3.jpeg
#   inflating: assessment_dataset/images/4.jpeg
#   inflating: assessment_dataset/images/5.jpeg
# ...

# %% [markdown]
# # MODEL IMPLEMENTATION:

# %%
! pip install torchmetrics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.2/519.2 kB 13.8 MB/s eta 0:00:00
# ...

# %%
import os
import torch
import torch.nn as nn
import numpy as np

from torchvision.models import resnet18, ResNet18_Weights
import torch.nn.functional as F
import cv2
import numpy as np
from typing import Tuple, List, Dict
import random
import matplotlib.pyplot as plt
import json
from pathlib import Path
from torch.utils.data import Dataset
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import torchmetrics
from torch.utils.tensorboard import SummaryWriter

# %%
class Model(nn.Module):
  def __init__(self, num_species: int):
    super(Model, self).__init__()
    pretrained_model = resnet18(pretrained=True)
    self.backbone = nn.Sequential(*list(pretrained_model.children())[:-2])
    ### Initialize the required Layers
    self.have_object = nn.Sequential(
        nn.Linear(512, 1),
    )
    self.cat_or_dog = nn.Sequential(
        nn.Linear(512, 128),
        nn.BatchNorm1d(128),
        nn.ReLU(),
        nn.Linear(128, 64),
        nn.BatchNorm1d(64),
        nn.ReLU(),
        nn.Linear(64, 1),
    )
    self.specie = nn.Sequential(
        nn.Linear(512, 128),
        nn.BatchNorm1d(128),
        nn.ReLU(),
        nn.Dropout(),
        nn.Linear(128, 64),
        nn.BatchNorm1d(64),
        nn.ReLU(),
        nn.Dropout(),
        nn.Linear(64, num_species),
    )
    self.bbox = nn.Sequential(
        nn.Linear(512, 128),
        nn.ReLU(),
        nn.Linear(128, 64),
        nn.ReLU(),
        nn.Linear(64, 4),
    )

  def forward(self, input):
    out_backbone = self.backbone(input)
    out_backbone = F.relu(out_backbone)
    out_backbone = nn.AdaptiveAvgPool2d((1, 1))(out_backbone)
    out_backbone = out_backbone.view(out_backbone.shape[0], -1)
    ### Write Forward Calls for the Model
    
    return {
        "bbox": self.bbox(out_backbone),
        "object": self.have_object(out_backbone),
        "cat_or_dog": self.cat_or_dog(out_backbone),
        "specie": self.specie(out_backbone)
    }

# %%
test_model = Model(num_species=9)
test_model
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 160MB/s]
# Model(
#   (backbone): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
# ...

# %% [markdown]
# ## Config
# #### All model related configuration, hyperparameters, dataset configs

# %%
class Config(object):
    '''
        a config utility class
    '''
    # training config
    checpoint_dir: str = "/content/trained_model"
    resume_weights_path = ""
    
    init_lr: float = 1e-3
    num_epochs: int = 20
    lr_drop_epochs = [5, 10, 15]
    lr_drop_factor = 0.1
    train_batch_size: int = 64
    val_batch_size: int = 16
    
    # Dataset config
    dataset_dir: str = "/content/assessment_dataset"
    input_image_wh: List[int] = [450, 300]
    mean: List[float] = [0.485, 0.456, 0.406]
    std: List[float] = [0.229, 0.224, 0.225]
    
    label_map = {
        "cat": 0,
        "dog": 1
    }
    
    species_label_map = {
        "basset_hound": 0,
        "Birman": 1, 
        "pomeranian": 2,
        "american_pit_bull_terrier": 3,
        "american_bulldog": 4,
        "Abyssinian": 5,
        "beagle": 6,
        "Persian": 7,
        "chihuahua": 8,
        "empty": 9
    }
    
    num_classes: int = len(label_map)
    num_species: int = len(species_label_map) - 1
    
    # loss weights
    bbox_loss_weight: float = 0.001
    object_loss_weight: float = 1.0
    cat_dog_loss_weight: float = 1.0
    species_loss_weight: float =  1.0

    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # CUSTOM DATALOADER IMPLEMENTATION

# %%
train_list = np.load('/content/assessment_dataset/train_list.npy', allow_pickle=True).tolist()
val_list = np.load('/content/assessment_dataset/val_list.npy', allow_pickle=True).tolist()
print('Total Train images = {} and val images = {}'.format(len(train_list), len(val_list)))
# Out:
# Total Train images = 832 and val images = 208

# %%
from bs4 import BeautifulSoup

def read_xml_file(path):
    with open(path, 'r') as f:
        data = f.read()
    bs_data = BeautifulSoup(data, 'xml')
    return {
        "cat_or_dog": bs_data.find("name").text,
        "xmin": int(bs_data.find("xmin").text),
        "ymin": int(bs_data.find("ymin").text),
        "xmax": int(bs_data.find("xmax").text),
        "ymax": int(bs_data.find("ymax").text),
        "specie": "_".join(path.split(os.sep)[-1].split("_")[:-1])
    }

# %% [markdown]
# ### Image utility functions - data augmentation

# %%
def read_image(image_path: str) -> np.ndarray:
    '''
        reads and return RGB image
        args:
            image_path: full path to image
        returns:
            ndarray of size [w, h, channel]
    '''
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    return image


def resize_image_and_bbox(image: np.ndarray, bbox: np.ndarray, target_wh: Tuple[int, int] = (450, 300)) -> Tuple[np.ndarray, np.ndarray]:
    '''
        resize image and bbox to target size
        args:
            image: ndarray of dimension [w, h, channel] - RGB image
            bbox: bounding box contain xmin, ymin, xmax, and ymax
            target_wh: widht and height 
        returns:
            Resized image and resized bbox
    '''
    orig_h, orig_w = image.shape[:2]
    resized_image = cv2.resize(image, target_wh)
    scale_x = target_wh[0] / orig_w
    scale_y = target_wh[1] / orig_h
    
    resized_bbox = np.array([bbox[0] * scale_x, bbox[1] * scale_y, bbox[2] * scale_x, bbox[3] * scale_y])
    
    return resized_image, resized_bbox


def horizontal_flip(image: np.ndarray, bbox: np.ndarray) -> Tuple[np.ndarray, np.ndarray]:
    '''
        Horizontally flip image and bbox
        args:
            image: ndarray of dimension [w, h, channel] - RGB image
            bbox: bounding box contain xmin, ymin, xmax, and ymax
        returns:
            Flipped image and bbox
    '''
    flipped_image = np.fliplr(image).copy()
    orig_w, orig_h = image.shape[:2]
    
    bbox_mask = np.zeros((orig_w, orig_h))
    bbox = bbox.astype(int)
    bbox_mask[bbox[1]:bbox[3], bbox[0]:bbox[2]] = 1
    
    flipped_mask = np.fliplr(bbox_mask).copy()
    
    cols, rows = np.nonzero(flipped_mask)
    xmin = np.min(rows)
    ymin = np.min(cols)
    xmax = np.max(rows)
    ymax = np.max(cols)
    
    flipped_bbox = np.array([xmin, ymin, xmax, ymax])
    
    return flipped_image, flipped_bbox

def crop_image_and_bbox(image: np.ndarray, bbox: np.ndarray, max_crop_percentage: float = 0.15) -> Tuple[np.ndarray, np.ndarray]:
    '''
        zoom in augmentation
        function randomly crops an image, randomness is controlled by max_crop_percentage e.g. 0.15 means max 30% of image can be cropped
    '''
    orig_h, orig_w = image.shape[:2]
    max_crop_row = int(np.floor(random.uniform(0, max_crop_percentage)*orig_w))
    max_crop_col = int(np.floor(random.uniform(0, max_crop_percentage)*orig_h))
    
    start_row = random.randint(0, max_crop_row)
    start_col = random.randint(0, max_crop_col)
    
    end_row = random.randint(orig_w-max_crop_row, orig_w)
    end_col = random.randint(orig_h-max_crop_col, orig_h)
    
    #print(start_row, start_col, end_row, end_col)
    cropped_image = image.copy()
    cropped_image = image[start_row:end_row, start_col:end_col, :]

    bbox_mask = np.zeros((orig_w, orig_h))
    bbox = bbox.astype(int)
    bbox_mask[bbox[1]:bbox[3], bbox[0]:bbox[2]] = 1
    
    cropped_bbox_mask = bbox_mask[start_row:end_row, start_col:end_col]
    
    cols, rows = np.nonzero(cropped_bbox_mask)
    if len(cols) == 0 or len(rows) == 0:
        cropped_bbox = np.zeros(4,)
    else:
        xmin = np.min(rows)
        ymin = np.min(cols)
        xmax = np.max(rows)
        ymax = np.max(cols)
        cropped_bbox = np.array([xmin, ymin, xmax, ymax])

#     cropped_bbox = bbox.copy()
#     cropped_bbox[0] = bbox[0]-start_col if bbox[0] >= start_col else 0
#     cropped_bbox[1] = bbox[1]-start_row if bbox[1] >= start_row else 0
#     cropped_bbox[2] = bbox[2]-end_col if bbox[2] <= end_col else end_col-start_col
#     cropped_bbox[3] = bbox[3]-end_row if bbox[3] <= end_row else end_row-start_row
#     print(cropped_image.shape)
    return resize_image_and_bbox(image=cropped_image, bbox=cropped_bbox, target_wh=(orig_w, orig_h))
    
    
def plot_bbox(bbox: np.ndarray) -> plt.Rectangle:
    return plt.Rectangle((bbox[0], bbox[1]), bbox[2]-bbox[0],bbox[3]-bbox[1],  color='green', fill=False, lw=5)

def plot_image_and_bbox(image:np.ndarray, bbox: np.ndarray):
    plt.imshow(image)
    plt.gca().add_patch(plot_bbox(bbox=bbox))

# %% [markdown]
# Testing image and bbox resize function

# %%
img = cv2.imread("/content/assessment_dataset/images/Abyssinian_193.jpg")
print(img.shape)
dummy_bbox = np.array([50, 100, 200, 200])
plot_image_and_bbox(img, dummy_bbox)
# Out:
# (225, 300, 3)

# %%
resize_image, resized_bbox = resize_image_and_bbox(image=img, bbox=dummy_bbox)
print(resize_image.shape)
dummy_bbox, resized_bbox
plot_image_and_bbox(resize_image, resized_bbox)
# Out:
# (300, 450, 3)

# %% [markdown]
# Testing crop image and bbox function

# %%
img = cv2.imread("/content/assessment_dataset/images/beagle_183.jpg")
print(img.shape)
dummy_bbox = np.array([0, 100, 200, 200])
plot_image_and_bbox(img, dummy_bbox)
# Out:
# (400, 500, 3)

# %%
cropped_image, cropped_bbox = crop_image_and_bbox(image=img, bbox=dummy_bbox)
print(cropped_image.shape)
plot_image_and_bbox(cropped_image, cropped_bbox)
dummy_bbox, cropped_bbox
# Out:
# (400, 500, 3)
# (array([  0, 100, 200, 200]),
#  array([  0.        ,  94.65648855, 247.43589744, 195.41984733]))

# %% [markdown]
# Testing horizontal flip function

# %%
img = cv2.imread("/content/assessment_dataset/images/american_bulldog_14.jpg")
dummy_bbox = np.array([50, 100, 200, 200])
plot_image_and_bbox(img, dummy_bbox)

# %%
flipped_img, flipped_box = horizontal_flip(image=img, bbox=dummy_bbox)
img.shape, flipped_img.shape
plot_image_and_bbox(flipped_img, flipped_box)

# %%
from PIL import Image
from typing import List, Union

import torchvision.transforms as transforms

from torch.utils.data import Dataset

# inheriting CustomDataset from pyTorch Dataset - this will allow to retain 
# the core properties of the pyTorch Dataset and we will only be 
# changing/modifying (overriding) the required functionalities
class CustomDataset(Dataset):
  def __init__(self, dataset_path: str, images_list: List[str], config: Config, train: bool = False):

    images_dir = os.path.join(dataset_path, "images")
    labels_dir = os.path.join(dataset_path, "labels")
    
    self.images_path = []
    self.labels = []
    self.transform = transforms.Compose([
        transforms.ToPILImage(),
        transforms.ToTensor(),
        transforms.Normalize(mean=config.mean, std=config.std)
    ])
    self.train = train
    
    for image_name in os.listdir(images_dir):
        image_name_wo_ext = Path(image_name).stem
        xml_full_path = os.path.join(labels_dir, image_name_wo_ext + ".xml")
        image_full_path = os.path.join(images_dir, image_name)
        if image_name_wo_ext in images_list and os.path.exists(xml_full_path):
            self.images_path.append(image_full_path)
            self.labels.append(read_xml_file(path=xml_full_path))

  def __len__(self):
    return len(self.images_path)

  def __getitem__(self, index):
    image_path = self.images_path[index]
    labels = self.labels[index]
    
    bbox = np.array([labels["xmin"], labels["ymin"], labels["xmax"], labels["ymax"]])
    
    image = read_image(image_path=image_path)
    h, w = image.shape[:2]
    
    # preprocessing 
    image, bbox = resize_image_and_bbox(image=image, bbox=bbox, target_wh=config.input_image_wh)
    
    # augmentations
    if self.train:
        if random.uniform(0, 1) > 0.5:
            image, bbox = horizontal_flip(image=image, bbox=bbox)
        if random.uniform(0, 1) > 0.5:
            image, bbox = crop_image_and_bbox(image=image, bbox=bbox)
        
    # mandatory transforms 
    image = self.transform(image)

    have_object = 1. if labels["cat_or_dog"] in config.label_map else 0.
    cat_or_dog_class_id  = config.label_map[labels["cat_or_dog"]]
    species_class_id = config.species_label_map[labels["specie"]]
    
    labels = {
        "width": config.input_image_wh[0], 
        "height": config.input_image_wh[1],
        "have_object": have_object,
        "cat_or_dog": cat_or_dog_class_id,
        "specie": species_class_id,
        "xmin": bbox[0] / config.input_image_wh[0],
        "ymin": bbox[1] / config.input_image_wh[1],
        "xmax": bbox[2] / config.input_image_wh[0],
        "ymax": bbox[3] / config.input_image_wh[1],
    }
    
    return image, labels

# %% [markdown]
# Testing custom dataloader

# %%
config = Config()
training_dataset = CustomDataset(dataset_path=config.dataset_dir, images_list=train_list, config=config, train=True)
training_dataloader = DataLoader(training_dataset, batch_size=1, shuffle=True)

# %%
training_batch = next(iter(training_dataloader))
img, labels = training_batch
img = img[0].permute(1, 2, 0)
img = img.numpy()
img = (img * config.std) + config.mean
print(img.shape)
labels
# Out:
# (300, 450, 3)
# {'width': tensor([450]),
#  'height': tensor([300]),
#  'have_object': tensor([1.], dtype=torch.float64),
#  'cat_or_dog': tensor([0]),
#  'specie': tensor([5]),
#  'xmin': tensor([0.2799], dtype=torch.float64),
#  'ymin': tensor([0.], dtype=torch.float64),
#  'xmax': tensor([0.8294], dtype=torch.float64),
#  'ymax': tensor([0.5734], dtype=torch.float64)}

# %%
bbox = [labels["xmin"].numpy(), labels["ymin"].numpy(), labels["xmax"].numpy(), labels["ymax"].numpy()]
plot_image_and_bbox(img, bbox)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # TRAINING LOOP IMPLEMENTATION

# %% [markdown]
# ## Initializations

# %%
# create training and validation data loaders
config = Config()
training_dataset = CustomDataset(dataset_path=config.dataset_dir, images_list=train_list, config=config, train=True)
training_dataloader = DataLoader(training_dataset, batch_size=config.train_batch_size, shuffle=True, num_workers=2)

validation_dataset = CustomDataset(dataset_path=config.dataset_dir, images_list=val_list, config=config, train=False)
val_dataloader = DataLoader(training_dataset, batch_size=config.val_batch_size, shuffle=True, num_workers=2)

# %%
def update_optimizer(optimizer: torch.optim, lr: float) -> torch.optim:
    '''
        function to update learning rate in optimizer
    '''
    for i, param_group in enumerate(optimizer.param_groups):
        param_group["lr"] = lr

def save_checkpoint(checkpoint_path: str, model: Model, optimizer: torch.optim, epoch: int, loss: float):
        torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'loss': loss,
                }, checkpoint_path)
        print('Saved {}'.format(checkpoint_path))
        
def save_best_checkpoint(checpoint_dir: str, best_metrics: Dict, current_metrics: Dict,
                         model: Model, optimizer: torch.optim, epoch: int, loss: float):

    if current_metrics["score_cat_or_dog"] > best_metrics["score_cat_or_dog"]:
        print('Current score_cat_or_dog = {} is greater than {}'.format(current_metrics["score_cat_or_dog"], best_metrics["score_cat_or_dog"]))
        print('Saving current checkpoint as best checkpoint (best.pt)')
        best_results_file = os.path.join(config.checpoint_dir, "best_resutlts.json")

        with open(best_results_file, 'w') as out_file:
            json.dump(current_metrics, out_file)
        save_checkpoint(checkpoint_path=os.path.join(checpoint_dir, 'best.pt'), epoch=epoch, model=model, optimizer=optimizer, loss=loss)
        
def load_checkpoint(checkpoint_path: str, model: Model, optimizer: torch.optim):
    print('Loading weights from {}'.format(checkpoint_path))
    checkpoint_dict = torch.load(checkpoint_path)
    model.load_state_dict(checkpoint_dict["model_state_dict"])
    optimizer.load_state_dict(checkpoint_dict["optimizer_state_dict"])
    epoch = checkpoint_dict['epoch']
    loss = checkpoint_dict['loss']
    print('Successfully loaded')
    return model, optimizer, epoch, loss

# %%
from torchmetrics.detection.mean_ap import MeanAveragePrecision
def test(model: Model, val_loader: DataLoader, config: Config):
    model.eval()
    def post_process_object(x, th=0.5):
        predicted_object_id = torch.where(x > th, 1.0, 0.0).squeeze(1).detach().cpu().numpy().tolist()
        return predicted_object_id

    def post_process_cat_or_dog(x, th=0.5):
        predicted_cat_or_dog_id = torch.where(x > th, 1.0, 0.0).squeeze(1).detach().cpu().numpy().tolist()
        return predicted_cat_or_dog_id

    def post_process_specie(x):
        predicted_specie_id = torch.argmax(x, dim=1).detach().cpu().numpy().tolist()
        # predicted_specie_id = x.detach().cpu().numpy().tolist()
        # print(len(predicted_specie_id))
        return predicted_specie_id

    def post_process_bbox(x):
        return x.detach().cpu().numpy().tolist()
    
    def convert_tensor_to_list(x):
        return x.detach().cpu().numpy().tolist()
    

    metric_object = torchmetrics.classification.BinaryF1Score()
    metric_cat_or_dog = torchmetrics.classification.BinaryF1Score()
    metric_specie = torchmetrics.classification.MulticlassF1Score(num_classes=config.num_species)
    metric_bbox = MeanAveragePrecision()

    object_predictions = []
    object_gt = []

    cat_or_dog_predictions = []
    cat_or_dog_gt = []

    specie_predictions = []
    specie_gt = []

    ap_50 = []
    map = []

    for i, data in enumerate(val_loader):
        inputs, labels = data

        inputs = inputs.to(config.device)

        # Make predictions for this batch
        outputs = model(inputs)

        object_gt.extend(convert_tensor_to_list(labels["have_object"]))
        object_predictions.extend(post_process_object(outputs["object"]))

        cat_or_dog_gt.extend(convert_tensor_to_list(labels["cat_or_dog"]))
        cat_or_dog_predictions.extend(post_process_cat_or_dog(outputs["cat_or_dog"]))

        specie_gt.extend(convert_tensor_to_list(labels["specie"]))
        specie_predictions.extend(post_process_specie(outputs["specie"]))

    score_object = metric_object(torch.tensor(object_gt), torch.tensor(object_predictions))
    score_cat_or_dog = metric_cat_or_dog(torch.tensor(cat_or_dog_gt), torch.tensor(cat_or_dog_predictions))
    score_specie = metric_specie(torch.tensor(specie_gt), torch.tensor(specie_predictions))
    score_bbox = 0#metric_bbox()

    out_metrics = {
        "score_object": score_object.cpu().numpy().tolist(),
        "score_cat_or_dog": score_cat_or_dog.cpu().numpy().tolist(),
        "score_specie": score_specie.cpu().numpy().tolist(),
        "score_bbox": score_bbox
    }

    return out_metrics

# %%
def train(model, optimizer, training_loader, epochs, config):
    tb_writer = SummaryWriter()
    os.makedirs(config.checpoint_dir, exist_ok=True)

    # Initialize Loss Functions
    have_object_loss = nn.BCEWithLogitsLoss()
    specie_loss = nn.CrossEntropyLoss()
    cat_or_dog_loss = nn.BCEWithLogitsLoss()
    bbox_loss = nn.L1Loss()#nn.SmoothL1Loss()#nn.MSELoss() 

    def train_one_epoch(epoch_index: int, tb_writer: SummaryWriter):
        running_loss = 0.
        last_loss = 0.
        model.train()

        # Here, we use enumerate(training_loader) instead of
        # iter(training_loader) so that we can track the batch
        # index and do some intra-epoch reporting
        for idx, data in enumerate(training_loader):
            # Every data instance is an input + label pair
            inputs, labels = data

            inputs = inputs.to(config.device).float()
            have_object = labels["have_object"].to(config.device)
            specie = labels["specie"].to(config.device)
            cat_or_dog = labels["cat_or_dog"].to(torch.float32).to(config.device)
            bbox = torch.stack((labels["xmin"], labels["ymin"], labels["xmax"], labels["ymax"]), axis=1).to(config.device)                

            outputs = model(inputs)

            loss_bbox = config.bbox_loss_weight * bbox_loss(outputs["bbox"], bbox)
            loss_cat_or_dog = config.cat_dog_loss_weight * cat_or_dog_loss(outputs["cat_or_dog"], cat_or_dog.unsqueeze(1))
            loss_object = config.object_loss_weight * have_object_loss(outputs["object"], have_object.unsqueeze(1))
            loss_specie = config.species_loss_weight * specie_loss(outputs["specie"], specie)

            loss =  loss_object +  loss_specie + loss_cat_or_dog + loss_bbox# Consolidate all individual losses
            tb_idx = (epoch_index*idx) + idx
            tb_writer.add_scalar("Loss/train_bbox", loss_bbox, tb_idx)
            tb_writer.add_scalar("Loss/train_have_object", loss_object, tb_idx)
            tb_writer.add_scalar("Loss/train_specie", loss_specie, tb_idx)
            tb_writer.add_scalar("Loss/train_cat_or_dog", loss_cat_or_dog, tb_idx)
            tb_writer.add_scalar("Loss/train_loss", loss, tb_idx)
            loss.cuda()
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # Gather data and report
            running_loss += loss.item()
            if (idx % 10 == 0) and idx != 0:
                last_loss = running_loss / 10 # loss per batch
                running_loss = 0.
        return last_loss

    for epoch_idx in range(epochs):
        model.train()
        # drop learnig rate
        if epoch_idx in config.lr_drop_epochs:
            current_lr = optimizer.param_groups[0]["lr"]
            updated_lr = current_lr * config.lr_drop_factor
            update_optimizer(optimizer=optimizer, lr=updated_lr)
            print(f'Reduced lr {current_lr} to {updated_lr}')


        # train for single epoch
        epoch_loss = train_one_epoch(epoch_index=epoch_idx, tb_writer=tb_writer)
        print(f' Epoch {epoch_idx} Loss : {epoch_loss}')

        # validation
        metrics = test(model=model, val_loader=val_dataloader, config=config)

        # save checkpoint
        current_checkpoint_save_path = os.path.join(config.checpoint_dir, "current.pt")
        save_checkpoint(checkpoint_path=current_checkpoint_save_path, model=model, optimizer=optimizer, epoch=epoch_idx, loss=epoch_loss)

        # best checkpoint 
        best_results_file = os.path.join(config.checpoint_dir, "best_resutlts.json")
        if not os.path.exists(best_results_file):
            with open(best_results_file, 'w') as out_file:
                json.dump(metrics, out_file)
            checkpoint_save_path = os.path.join(config.checpoint_dir, 'best.pt')
            save_checkpoint(checkpoint_path=checkpoint_save_path, model=model, optimizer=optimizer, epoch=epoch_idx, loss=epoch_loss)
        else:
            with open(best_results_file, 'r') as best_file:
                best_metrics = json.load(best_file)

            save_best_checkpoint(checpoint_dir=config.checpoint_dir, best_metrics=best_metrics, 
                                current_metrics=metrics, model=model, optimizer=optimizer, epoch=epoch_idx, loss=epoch_loss)

            print(metrics)
    tb_writer.flush()

# %%
model = Model(num_species=config.num_species)
optimizer = torch.optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=config.init_lr)
model = model.cuda()
if config.resume_weights_path:
    model.cuda()
    model, optimizer, epoch, loss = load_checkpoint(checkpoint_path=config.resume_weights_path, model=model, optimizer=optimizer)
    print(f'Previous weights were saved at Epoch {epoch} with Loss : {loss}')
    model.cuda()
train(model=model, optimizer=optimizer, training_loader=training_dataloader, epochs=config.num_epochs, config=config)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
#  Epoch 0 Loss : 2.8294546073900277
# Saved /content/trained_model/current.pt
# Saved /content/trained_model/best.pt
#  Epoch 1 Loss : 1.9466040798622442
# Saved /content/trained_model/current.pt
# Current score_cat_or_dog = 0.8951048851013184 is greater than 0.8387909531593323
# Saving current checkpoint as best checkpoint (best.pt)
# ...

# %%
data = next(iter(val_dataloader))
inputs, labels = data
model.eval()
inputs = inputs.cuda().float()
output = model(inputs)

# %%
output
# Out:
# {'bbox': tensor([[0.2858, 0.1188, 0.8527, 0.6152],
#          [0.3011, 0.0870, 0.7776, 0.5415],
#          [0.3392, 0.0907, 0.8350, 0.4826],
#          [0.3246, 0.0834, 0.8558, 0.5491],
#          [0.3801, 0.1127, 0.8088, 0.5285],
#          [0.3269, 0.1188, 0.8582, 0.6205],
#          [0.2989, 0.0873, 0.9042, 0.7681],
#          [0.3203, 0.1034, 0.8779, 0.5866],
#          [0.2773, 0.1188, 0.8094, 0.6042],
#          [0.3533, 0.1373, 0.8326, 0.5664],
#          [0.3431, 0.1167, 0.8327, 0.4976],
#          [0.3652, 0.1672, 0.8469, 0.5589],
#          [0.2819, 0.0388, 0.8892, 0.6090],
#          [0.2698, 0.0811, 0.9270, 0.8120],
#          [0.3168, 0.0567, 0.8766, 0.5316],
#          [0.3621, 0.0916, 0.8550, 0.4783]], device='cuda:0',
#         grad_fn=<AddmmBackward0>),
#  'object': tensor([[5.8171],
#          [6.0356],
#          [6.0620],
#          [6.5262],
#          [5.6780],
#          [6.4184],
#          [7.0601],
#          [6.5322],
#          [5.4383],
# ...

# %%
labels

# %%
from PIL import ImageDraw
species_label_map = {
        0: "basset_hound",
        1: "Birman", 
        2:"pomeranian",
        3:"american_pit_bull_terrier",
        4: "american_bulldog",
        5: "Abyssinian",
        6: "beagle",
        7: "Persian",
        8: "chihuahua",
        9: "empty"
    }
cat_or_dog_map = {
    0: "Cat",
    1: "Dog"
}

def visualize(model_weights, image_folder_path, output_folder="output"):
    MEAN = [0.485, 0.456, 0.406]
    STD = [0.229, 0.224, 0.225]
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    model = Model(num_species=9)
    checkpoint_dict = torch.load(model_weights)
    model.load_state_dict(checkpoint_dict["model_state_dict"])
    
    model = model.to(device)
    
    model.eval()
    out_dict = {}
    
    images_names = images_list=os.listdir(image_folder_path)
    for image_name in images_names:
        image_full_path = os.path.join(image_folder_path, image_name)
        img = read_image(image_path=image_full_path)
        orig_img = img.copy()
        img = img / 255.
        img = (img - MEAN) / STD
        img = np.expand_dims(img, axis=0)
        input_img = torch.tensor(img).to(device).float()
        input_img = input_img.permute(0, 3, 1, 2)
        
        outputs = model(input_img)
        
        has_object = torch.where(outputs["object"] > 0.5, True, False).squeeze(1).detach().cpu().numpy()
        cat_or_dog = cat_or_dog_map[torch.where(outputs["cat_or_dog"] > 0.5, 1, 0).squeeze(1).detach().cpu().numpy().tolist()[0]]
        specie = torch.argmax(outputs["specie"], dim=1).detach().cpu().numpy().tolist()
        specie_class = species_label_map[specie[0]]
        
        xmin = outputs["bbox"][0][0].detach().cpu().numpy().tolist()[0]
        ymin = outputs["bbox"][0][1].detach().cpu().numpy().tolist()[0]
        xmax = outputs["bbox"][0][2].detach().cpu().numpy().tolist()[0]
        ymax = outputs["bbox"][0][3].detach().cpu().numpy().tolist()[0]
        out_dict[image_name] = {
            "has_object": has_object,
            "cat_or_dog": cat_or_dog,
            "specie": specie_class,
            "xmin": xmin,
            "ymin" : ymin,
            "xmax" : xmax,
            "ymax" : ymax
        }
        
        h, w = orig_img.shape[:2]
        bbox = [xmin*w, ymin*h, xmax*w, ymax*h]
        out_img = cv2.rectangle(orig_img, (int(bbox[0]), int(bbox[1])), (int(bbox[2]), int(bbox[3])), (255, 0, 0), 3)
        out_img = cv2.cvtColor(out_img, cv2.COLOR_BGR2RGB)
        os.makedirs(output_folder, exist_ok=True)
        save_path = os.path.join(output_folder, image_name)
        cv2.imwrite(save_path, out_img)
        
    return out_dict

# %%
visualize(
    model_weights="/trained_models_faisal/best.pt", 
    image_folder_path="/ml-engineer-assessment-dataset/assessment_dataset/images", 
    output_folder="/ml-engineer-assessment-dataset/assessment_dataset/images_out")
